# %%
import numpy as np
from Utilities import PlotImages

# %%
data = np.load("/work/MA490_DeepLearning/Share/Dice/CleanedDiceData.npz", allow_pickle=True)

# %%
data.files
# Out:
# ['images', 'labels']

# %%
images = data["images"]
labels = data["labels"]

# %%
print(images.shape)
print(images[0].shape)
print(labels.shape)
# Out:
# (2768,)
# (622, 723, 3)
# (2768,)

# %%
PlotImages(1000, 15, 3, 5, images, labels)
